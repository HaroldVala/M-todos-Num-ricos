# %% [markdown]
# # Liberias

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Operaciones

# %%
#Matriz inicial
A = np.array([[50,-4],
              [-4, 5]])

#Vector Inicial
V_0 = np.array([[1],
                [3]])

#Iteraciones
n = 6 #Python cuenta desde 0
iteraciones = range(1,n)

# Iteraciones para potencias negativas
iteraciones_pq = range(-1, -n, -1)  # Esto generará una secuencia de -1 a -n

# %% [markdown]
# # Valor propio mas grande

# %%
# Crear un DataFrame vacío para almacenar los resultados
matriz_simetrica_df = pd.DataFrame(columns=['i', 'Vi'])

# %% [markdown]
# ## Vi

# %%
for i in iteraciones:
    # Elevar la matriz A a la i-ésima potencia
    A_i = np.linalg.matrix_power(A, i)

    # Multiplicar la matriz elevada por el vector V_0
    resultado = A_i @ V_0


    # Redondear el resultado a 4 decimales y convertirlo a una lista
    resultado_redondeado = resultado.flatten().tolist()

    # Agregar el resultado al DataFrame
    matriz_simetrica_df.loc[i-1] = [i, resultado_redondeado]

# %% [markdown]
# ## ||Vi||

# %% [markdown]
# **square** se usa para elevar un numero al cuadrado
#
# **sqrt** Se usa para sacar raiz

# %%
# Función para calcular la norma de un vector
def calcular_norma(vector):
    suma_cuadrados = sum(numero**2 for numero in vector)
    return suma_cuadrados ** 0.5

# Aplicar la función a cada elemento de la columna "Vi" y crear la nueva columna "||Vi||"
matriz_simetrica_df['||Vi||'] = matriz_simetrica_df['Vi'].apply(calcular_norma)

# %% [markdown]
# ## 	||Vi||/||Vi-1||

# %%
matriz_simetrica_df["||Vi||/||Vi-1||"] = matriz_simetrica_df['||Vi||'].div(matriz_simetrica_df['||Vi||'].shift(1))

# %% [markdown]
# #  Valor propio mas pequeño

# %% [markdown]
# ## Vi

# %%
# DataFrame para almacenar los resultados
matriz_simetrica_pq_df = pd.DataFrame(columns=['i', 'Vi'])

# Bucle para calcular A elevado a la i-ésima potencia negativa y multiplicarlo por V_0
for i in iteraciones_pq:
    # Elevar la matriz A a la i-ésima potencia negativa
    A_i = np.linalg.matrix_power(A, i)

    # Multiplicar la matriz elevada por el vector V_0
    resultado = A_i @ V_0

    # Redondear el resultado a 4 decimales y convertirlo a una lista
    resultado_Vi = resultado.flatten().tolist()

    # Agregar el resultado al DataFrame
    matriz_simetrica_pq_df.loc[-i] = [-i, resultado_Vi]

# %% [markdown]
# ## ||Vi|| Norma o Magnitud

# %%
# Función para calcular la norma de un vector
def calcular_norma(vector):
    return np.sqrt(sum(np.square(vector)))

# Aplicar la función a cada elemento de la columna "Vi" y crear la nueva columna "||Vi||"
matriz_simetrica_pq_df['||Vi||'] = matriz_simetrica_pq_df['Vi'].apply(calcular_norma)

# %% [markdown]
# ## ||Vi||/||Vi-1||

# %%
matriz_simetrica_pq_df["||Vi||/||Vi-1||"] = 1/(matriz_simetrica_pq_df['||Vi||'].div(matriz_simetrica_pq_df['||Vi||'].shift(1)))

# %% [markdown]
# # Resultados

# %%
valores_propios = np.linalg.eigvals(A)

# %%
pd.options.display.float_format = '{:,.5f}'.format

# %%
print("Los valores propios de la matriz A maximos son:")
print(np.round(valores_propios[0],5))
matriz_simetrica_df
# Out:
# Los valores propios de la matriz A maximos son:
# 50.35279
#    i                      Vi            ||Vi||  ||Vi||/||Vi-1||
# 0  1                [38, 11]          39.56008              NaN
# 1  2             [1856, -97]       1,858.53302         46.98001
# 2  3          [93188, -7909]      93,523.02190         50.32088
# 3  4      [4691036, -412297]   4,709,119.61724         50.35252
# 4  5  [236200988, -20825629] 237,117,299.14838         50.35279

# %%
print("Los valores propios de la matriz A minimos son:")
print(np.round(valores_propios[1],6))
matriz_simetrica_pq_df
# Out:
# Los valores propios de la matriz A minimos son:
# 4.64721
#    i                                              Vi  ||Vi||  ||Vi||/||Vi-1||
# 1  1       [0.07264957264957266, 0.6581196581196582] 0.66212              NaN
# 2  2     [0.012802249981737162, 0.14186573160932137] 0.14244          4.64832
# 3  3      [0.0026986075912221, 0.030532032394841955] 0.03065          4.64722
# 4  4   [0.0005795776390405057, 0.006570068590200796] 0.00660          4.64721
# 5  5  [0.0001246930023760928, 0.0014137681199410334] 0.00142          4.64721
